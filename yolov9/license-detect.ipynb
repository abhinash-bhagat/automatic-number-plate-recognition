# %%
# !pip install -r /content/drive/MyDrive/License-Detection/requirements.txt

# %%
# !python /content/drive/MyDrive/License-Detection/yolov9/train_dual.py --workers 8 --batch 8 --device 0 --epochs 150 --data /content/drive/MyDrive/License-Detection/yolov9/data.yaml --weights /content/drive/MyDrive/License-Detection/yolov9/yolov9-c.pt --cfg /content/drive/MyDrive/License-Detection/yolov9/models/detect/yolov9-c.yaml --hyp /content/drive/MyDrive/License-Detection/yolov9/data/hyps/hyp.scratch-high.yaml

# %%
# !python /content/drive/MyDrive/License-Detection/yolov9/detect.py --conf 0.1 --weights /content/drive/MyDrive/License-Detection/yolov9/runs/train/exp/weights/best.pt --source /content/drive/MyDrive/License-Detection/test.mp4

# %%
import easyocr

# %%
# !python /content/drive/MyDrive/License-Detection/yolov9/anpr_predictor.py --weights /content/drive/MyDrive/License-Detection/yolov9/runs/train/exp/weights/best.pt --source /content/drive/MyDrive/License-Detection/high.mp4
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# anpr_predictor: weights=['/content/drive/MyDrive/License-Detection/yolov9/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/License-Detection/high.mp4, data=drive/MyDrive/License-Detection/yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/License-Detection/yolov9/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 2024-4-20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50698278 parameters, 0 gradients, 236.6 GFLOPs
# video 1/1 (1/396) /content/drive/MyDrive/License-Detection/high.mp4: 384x640 3 License_Plates, 143.4ms
# ...
